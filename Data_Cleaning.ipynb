# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("student_dropout_dataset 2.csv")
print(df.isnull().sum())
# Out:
# student_id                           0
# age                                  0
# gender                               0
# socioeconomic_status                 0
# parental_education_level           519
# family_background                    0
# first_generation_student             0
# gpa                                  0
# previous_academic_performance        0
# subject_failure_count                0
# credits_completed                    0
# course_load                          0
# scholarship_status                   0
# attendance_rate                      0
# class_participation_score            0
# assignment_submission_rate           0
# quiz_completion_rate                 0
# time_spent_on_learning_platform      0
# login_frequency                      0
# engagement_score                     0
# learning_style                       0
# motivation_level                     0
# peer_interaction_score               0
# counseling_sessions_attended         0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#                age          gpa  subject_failure_count  credits_completed  \
# count  5000.000000  5000.000000            5000.000000        5000.000000
# mean     20.933200     2.742596               2.523600          70.093400
# std       2.546298     0.729428               1.717799          29.124449
# min      17.000000     1.500000               0.000000          20.000000
# 25%      19.000000     2.100000               1.000000          45.000000
# 50%      21.000000     2.750000               3.000000          70.000000
# 75%      23.000000     3.370000               4.000000          95.000000
# max      25.000000     4.000000               5.000000         119.000000
#
#        course_load  attendance_rate  class_participation_score  \
# count  5000.000000      5000.000000                5000.000000
# mean      5.013200        69.710800                   5.024600
# std       1.417119        17.213391                   3.181323
# ...

# %%
df = df.dropna()
print(df.isnull().sum())
# Out:
# student_id                         0
# age                                0
# gender                             0
# socioeconomic_status               0
# parental_education_level           0
# family_background                  0
# first_generation_student           0
# gpa                                0
# previous_academic_performance      0
# subject_failure_count              0
# credits_completed                  0
# course_load                        0
# scholarship_status                 0
# attendance_rate                    0
# class_participation_score          0
# assignment_submission_rate         0
# quiz_completion_rate               0
# time_spent_on_learning_platform    0
# login_frequency                    0
# engagement_score                   0
# learning_style                     0
# motivation_level                   0
# peer_interaction_score             0
# counseling_sessions_attended       0
# stress_level                       0
# ...

# %%
new_file = "/content/cleaned_data.csv"
df.to_csv(new_file, index=False)
