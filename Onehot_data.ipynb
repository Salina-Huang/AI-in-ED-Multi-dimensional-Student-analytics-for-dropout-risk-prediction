# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from google.colab import files

# Load the dataset from GitHub repository
data = pd.read_csv('https://raw.githubusercontent.com/Salina-Huang/AI-in-ED-Multi-dimensional-Student-analytics-for-dropout-risk-prediction/refs/heads/main/cleaned_data.csv')

# Create a copy of the data to avoid modifying the original dataset
data_encoded = data.copy()
data_encoded = data_encoded.drop('student_id', axis=1) # Remove student_id column as it's typically not used for machine learning models
data_encoded = data_encoded.drop('first_generation_student', axis=1)
data_encoded = data_encoded.drop('scholarship_status', axis=1)
# Define numerical columns that need to be scaled
categorical_columns = [
    'socioeconomic_status', 'parental_education_level', 'family_background',
     'previous_academic_performance',
     'learning_style', 'stress_level', 'gender'
]
# Filter numerical columns to only include those present in the dataset
categorical_columns = [col for col in categorical_columns if col in data_encoded.columns]

print("Categorical columns for one-hot encoding:")
print(categorical_columns)

data_final = pd.get_dummies(data_encoded, columns=categorical_columns, drop_first=True)

print(f"Data shape before encoding: {data_encoded.shape}")
print(f"Data shape after encoding: {data_final.shape}")

# Check for any remaining non-numeric columns that might have been missed
remaining_non_numeric = data_final.select_dtypes(include=['object']).columns
if len(remaining_non_numeric) > 0:
    print(f"Additional non-numeric columns found: {list(remaining_non_numeric)}")
    data_final = pd.get_dummies(data_final, columns=remaining_non_numeric, drop_first=True)

# Define numerical columns that need to be scaled
numeric_columns_to_scale = [
    'age', 'gpa', 'subject_failure_count', 'credits_completed',
    'course_load', 'attendance_rate', 'class_participation_score',
    'assignment_submission_rate', 'quiz_completion_rate',
    'time_spent_on_learning_platform', 'login_frequency',
    'engagement_score', 'motivation_level', 'peer_interaction_score',
    'counseling_sessions_attended'
]
# Filter numerical columns to only include those present in the dataset
numeric_columns_to_scale = [col for col in numeric_columns_to_scale if col in data_final.columns]

print(f"Numeric columns to scale: {len(numeric_columns_to_scale)}")

# Initialize StandardScaler for standardization
scaler = StandardScaler()
data_final[numeric_columns_to_scale] = scaler.fit_transform(data_final[numeric_columns_to_scale]) # Apply standardization to numerical columns (mean=0, std=1)

print("Processed data sample:")
print(data_final.head())

print(f"Final data shape: {data_final.shape}")

# Save the processed data to a CSV file
output_filename = 'encoded_data_onehot.csv'
data_final.to_csv(output_filename, index=True)
# Download the file in Google Colab environment
files.download(output_filename)

print(f"File '{output_filename}' downloaded successfully")
# Out:
# Categorical columns for one-hot encoding:
# ['socioeconomic_status', 'parental_education_level', 'family_background', 'previous_academic_performance', 'learning_style', 'stress_level', 'gender']
# Data shape before encoding: (4481, 23)
# Data shape after encoding: (4481, 33)
# Numeric columns to scale: 15
# Processed data sample:
#         age       gpa  subject_failure_count  credits_completed  course_load  \
# 0  0.017472 -0.493167              -0.870832          -0.031773    -0.715848
# 1  1.583324 -1.330171               1.459187          -1.133052    -0.009614
# 2 -0.765454  1.551317              -0.870832           0.105887    -1.422082
# 3 -0.373991  0.453608              -0.870832           1.069506     1.402854
# 4  1.191861 -0.753873               0.294177          -0.444753    -1.422082
#
#    attendance_rate  class_participation_score  assignment_submission_rate  \
# 0         1.401647                  -1.257148                    1.588839
# 1        -1.437084                   1.255326                   -1.352542
# 2         0.358848                   1.569385                   -1.448980
# 3        -1.552951                  -1.257148                   -1.159664
# 4         1.401647                  -0.943089                   -0.966787
#
#    quiz_completion_rate  time_spent_on_learning_platform  ...  \
# 0             -1.425076                         1.557305  ...
# 1             -1.080446                         1.225307  ...
# 2             -1.425076                         0.948642  ...
# 3             -1.295840                        -0.969568  ...
# 4             -0.218873                        -0.121129  ...
#
#    family_background_Single Parent  previous_academic_performance_Low  \
# 0                            False                              False
# 1                            False                              False
# 2                            False                              False
# 3                            False                               True
# 4                             True                              False
#
#    previous_academic_performance_Medium  learning_style_Kinesthetic  \
# 0                                  True                       False
# 1                                 False                        True
# 2                                  True                       False
# 3                                 False                       False
# 4                                  True                       False
#
#    learning_style_Mixed  learning_style_Visual  stress_level_Low  \
# 0                 False                   True             False
# 1                 False                  False             False
# 2                  True                  False             False
# 3                 False                  False             False
# 4                 False                  False             False
#
#    stress_level_Medium  gender_Male  gender_Other
# 0                 True         True         False
# 1                False        False         False
# 2                 True         True         False
# 3                 True         True         False
# 4                 True        False         False
#
# [5 rows x 33 columns]
# Final data shape: (4481, 33)
# File 'encoded_data_onehot.csv' downloaded successfully
