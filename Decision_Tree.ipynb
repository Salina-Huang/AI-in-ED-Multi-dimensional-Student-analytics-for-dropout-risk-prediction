# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder


df = pd.read_csv('/content/cleaned_data.csv')
X = df.drop(['student_id', 'dropout_status'], axis=1)
y = df['dropout_status']

categorical_cols = X.select_dtypes(include=['object']).columns
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])

rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X, y)

importances = rf.feature_importances_

feature_importances = pd.DataFrame({'feature': X.columns, 'score': importances})

feature_importances = feature_importances.sort_values(by='score', ascending=False).reset_index(drop=True)

feature_importances
# Out:
#                             feature     score
# 0                   attendance_rate  0.270761
# 1                               gpa  0.226594
# 2                  engagement_score  0.166856
# 3                      stress_level  0.095844
# 4                 credits_completed  0.024229
# 5        assignment_submission_rate  0.023308
# 6   time_spent_on_learning_platform  0.022510
# 7              quiz_completion_rate  0.021330
# 8                   login_frequency  0.019215
# 9         class_participation_score  0.014288
# 10           peer_interaction_score  0.014267
# 11                              age  0.013306
# 12            subject_failure_count  0.010524
# 13     counseling_sessions_attended  0.010127
# 14                      course_load  0.009945
# 15                 motivation_level  0.009820
# 16                   learning_style  0.008437
# 17         parental_education_level  0.007606
# 18                family_background  0.007059
# 19    previous_academic_performance  0.005890
# 20             socioeconomic_status  0.005478
# 21                           gender  0.005343
# 22         first_generation_student  0.003955
# 23               scholarship_status  0.003309
